# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import scipy.stats as st
from scipy.stats import linregress

# Import API key
from config import api_key

temp_units = "imperial"

#citipy to determine lat/long
from citipy import citipy

lat_range= (-90, 90)
long_range = (-180, 180)

url = "http://api.openweathermap.org/data/2.5/weather?"
query_url = f"{url}appid={api_key}&units={temp_units}&q="
output_data = "Output/city_data.csv"

# %% [markdown]
# ## Generate Cities List

# %%
#empty list for holding lat/long and city names
lats_longs = []
city_names = []

#create random set of lat/longs
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
longs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lats_longs = zip(lats, longs)

#loop through lats_longs to find coordinates using citipy and add unique names to list
for coordinates in lats_longs:
    city_name = citipy.nearest_city(coordinates[0], coordinates[1]).city_name

    if city_name not in city_names:
        city_names.append(city_name)
#print city count    
city_count = len(city_names)
print(f' The number of cities to look for is {city_count}')
# Out:
#  The number of cities to look for is 632

# %%
#check json response
weather_response_json = requests.get(query_url + city_name).json()
print(json.dumps(weather_response_json, sort_keys=True, indent=2))
# Out:
# {
#   "base": "stations",
#   "clouds": {
#     "all": 57
#   },
#   "cod": 200,
#   "coord": {
#     "lat": 1.65,
#     "lon": 14.58
#   },
#   "dt": 1600208254,
#   "id": 2255304,
#   "main": {
#     "feels_like": 77.22,
#     "grnd_level": 965,
#     "humidity": 93,
#     "pressure": 1013,
#     "sea_level": 1013,
#     "temp": 71.13,
#     "temp_max": 71.13,
#     "temp_min": 71.13
#   },
#   "name": "S\u00e9mb\u00e9",
#   "rain": {
#     "1h": 1.33
#   },
#   "sys": {
#     "country": "CG",
#     "sunrise": 1600145595,
#     "sunset": 1600189234
#   },
#   "timezone": 3600,
#   "visibility": 10000,
#   "weather": [
#     {
#       "description": "moderate rain",
#       "icon": "10n",
#       "id": 501,
#       "main": "Rain"
#     }
#   ],
#   "wind": {
#     "deg": 238,
#     "speed": 1.86
#   }
# }

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Starting URL for Weather Map API Call
query_url = f"{url}appid={api_key}&units={temp_units}&q="

#create new lists for city data
lat = []
long = []
temp = []
temp_max = []
humidity = [] 
cloudy = []
windspeed = []
name = []
country = []
date = []
#set count for timer
city_counter = 0

#set record counter starting with 1
counter = 1

# for loop to determine data for new lists with try/except    
for i, city in enumerate(city_names):
    
    if (i % 50 == 0 and i >= 50):        
        counter = 0
        query_url
        counter+=1
    try:
        response = requests.get(query_url + city).json()
        lat.append(response['coord']['lat'])
        long.append(response['coord']['lon'])
        temp.append(response['main']['temp'])
        temp_max.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudy.append(response['clouds']['all'])
        windspeed.append(response['wind']['speed'])
        name.append(response['name'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        print(f"City Count {city_counter} : {city}")      
        city_counter += 1
    except:
        #print log
        print("City not found! Skipping...")
        #pass
    #if counter == maxattempts:
        #time.sleep(60)
        #counter = 0

              
print(f"-----------------------")
print(f"Data Retrieval Complete")
print(f"{city_counter} Records Found")
print(f"-----------------------")
# Out:
# City Count 0 : jennings
# City Count 1 : bluff
# City Count 2 : kapaa
# City Count 3 : lebu
# City Count 4 : grand-santi
# City Count 5 : atuona
# City Count 6 : staryy nadym
# City Count 7 : rikitea
# City Count 8 : norden
# City Count 9 : mataura
# City Count 10 : albany
# City not found! Skipping...
# City Count 11 : qaanaaq
# City Count 12 : ostrovnoy
# City Count 13 : vilhena
# City Count 14 : mildura
# City Count 15 : punta arenas
# City Count 16 : talnakh
# City Count 17 : gebog
# City Count 18 : huarmey
# City Count 19 : mackay
# City Count 20 : jamestown
# City Count 21 : mar del plata
# City not found! Skipping...
# City Count 22 : richards bay
# City Count 23 : shiraz
# City Count 24 : hilo
# City Count 25 : dicabisagan
# City Count 26 : vestmannaeyjar
# City Count 27 : busselton
# City Count 28 : dunedin
# City Count 29 : bloemfontein
# City Count 30 : mizan teferi
# City Count 31 : atasu
# City Count 32 : new norfolk
# City Count 33 : mujiayingzi
# City Count 34 : longyearbyen
# City Count 35 : dandong
# City Count 36 : butaritari
# City not found! Skipping...
# City Count 37 : saint-philippe
# City Count 38 : nyimba
# City Count 39 : barrow
# City Count 40 : karaton
# City Count 41 : bredasdorp
# City Count 42 : hasaki
# City Count 43 : port alfred
# City Count 44 : georgetown
# City Count 45 : sao felix do xingu
# City Count 46 : ribeira grande
# City Count 47 : byron bay
# City Count 48 : iqaluit
# City Count 49 : provideniya
# City Count 50 : hithadhoo
# City not found! Skipping...
# City Count 51 : ushuaia
# City not found! Skipping...
# City not found! Skipping...
# City Count 52 : storsteinnes
# City Count 53 : slave lake
# City Count 54 : ukiah
# City Count 55 : honiara
# City Count 56 : dolores
# City Count 57 : sayyan
# City Count 58 : cape town
# City Count 59 : nome
# City Count 60 : arraial do cabo
# City Count 61 : pevek
# City Count 62 : krutikha
# City Count 63 : port elizabeth
# City Count 64 : zwettl
# City Count 65 : half moon bay
# City Count 66 : tura
# City Count 67 : egvekinot
# City Count 68 : ambon
# City not found! Skipping...
# City Count 69 : dikson
# City Count 70 : bagdarin
# City Count 71 : san patricio
# City not found! Skipping...
# City Count 72 : atambua
# City Count 73 : lekoni
# City Count 74 : houma
# City Count 75 : kodiak
# City Count 76 : beringovskiy
# City Count 77 : hobart
# City Count 78 : norman wells
# City Count 79 : chuy
# City Count 80 : saskylakh
# City Count 81 : lusambo
# City Count 82 : jeremie
# City Count 83 : shimoda
# City Count 84 : acapulco
# City Count 85 : broken hill
# City Count 86 : pangnirtung
# City Count 87 : fortuna
# City not found! Skipping...
# City Count 88 : vaini
# City Count 89 : diffa
# City Count 90 : kahului
# City Count 91 : lagoa
# City Count 92 : san vicente
# City Count 93 : galle
# City Count 94 : vagur
# City Count 95 : alofi
# City not found! Skipping...
# City Count 96 : airai
# City Count 97 : saldanha
# City Count 98 : mahebourg
# City Count 99 : torbay
# City Count 100 : santa cruz
# City Count 101 : sompeta
# City Count 102 : east london
# City Count 103 : puerto ayora
# City Count 104 : bambous virieux
# City Count 105 : nyurba
# City not found! Skipping...
# City Count 106 : polovinnoye
# City Count 107 : pathein
# City Count 108 : lubango
# City Count 109 : yining
# City Count 110 : road town
# City Count 111 : sobolevo
# City Count 112 : yellowknife
# City Count 113 : san pedro del pinatar
# City Count 114 : saint-paul
# City Count 115 : masagua
# City Count 116 : ornes
# City Count 117 : bubaque
# City Count 118 : medvezhyegorsk
# City Count 119 : sangmelima
# City Count 120 : sao joao de pirabas
# City Count 121 : codajas
# City Count 122 : hami
# City Count 123 : alyangula
# City Count 124 : vicente guerrero
# City Count 125 : kalikino
# City Count 126 : lantana
# City Count 127 : tanabe
# City Count 128 : calvinia
# City not found! Skipping...
# City Count 129 : kruisfontein
# City Count 130 : avarua
# City Count 131 : skuodas
# City Count 132 : thompson
# City Count 133 : upernavik
# City Count 134 : nikolskoye
# City Count 135 : constitucion
# City Count 136 : pisco
# City Count 137 : tabou
# City Count 138 : raga
# City Count 139 : batagay
# City Count 140 : leningradskiy
# City Count 141 : castro marim
# City Count 142 : san andres
# City not found! Skipping...
# City Count 143 : haapiti
# City Count 144 : sao joao da barra
# City Count 145 : mubi
# City Count 146 : standerton
# City Count 147 : bethel
# City Count 148 : bagar
# City Count 149 : tahara
# City Count 150 : puerto escondido
# City Count 151 : ancud
# City Count 152 : yulara
# City Count 153 : kisangani
# City Count 154 : marzuq
# City Count 155 : codrington
# City Count 156 : hermanus
# City Count 157 : vila velha
# City Count 158 : tiznit
# City Count 159 : gat
# City Count 160 : abapo
# City not found! Skipping...
# City Count 161 : bumba
# City Count 162 : petaluma
# City Count 163 : narsaq
# City Count 164 : plettenberg bay
# City Count 165 : touros
# City Count 166 : dingle
# City Count 167 : baculin
# City Count 168 : cabo san lucas
# City Count 169 : tuktoyaktuk
# City Count 170 : vilyuysk
# City Count 171 : mount isa
# City Count 172 : marcali
# City Count 173 : ewo
# City Count 174 : rio grande
# City Count 175 : barra patuca
# City Count 176 : carnarvon
# City Count 177 : goba
# City not found! Skipping...
# City Count 178 : sanming
# City Count 179 : geraldton
# City Count 180 : nisia floresta
# City not found! Skipping...
# City Count 181 : cherskiy
# City Count 182 : simi
# City Count 183 : fatsa
# City Count 184 : rehoboth
# City Count 185 : anadyr
# City Count 186 : olinda
# City Count 187 : bowen
# City not found! Skipping...
# City Count 188 : seoul
# City not found! Skipping...
# City Count 189 : olafsvik
# City Count 190 : victoria
# City Count 191 : chokurdakh
# City Count 192 : quatre cocos
# City Count 193 : ponta do sol
# City not found! Skipping...
# City Count 194 : port moresby
# City Count 195 : lahij
# City not found! Skipping...
# City Count 196 : piravam
# City Count 197 : santa barbara
# City Count 198 : luderitz
# City Count 199 : kirakira
# City Count 200 : dabola
# City Count 201 : barabai
# City Count 202 : portland
# City Count 203 : aguimes
# City Count 204 : castro
# City Count 205 : banda aceh
# City Count 206 : dongsheng
# City Count 207 : benguela
# City Count 208 : cidreira
# City Count 209 : san carlos de bariloche
# City Count 210 : lorengau
# City Count 211 : naze
# City Count 212 : gimli
# City Count 213 : jaque
# City not found! Skipping...
# City Count 214 : roma
# City Count 215 : comodoro rivadavia
# City Count 216 : saint george
# City Count 217 : la rioja
# City Count 218 : namibe
# City Count 219 : zyryanka
# City Count 220 : labuhan
# City not found! Skipping...
# City Count 221 : ust-tsilma
# City Count 222 : suez
# City Count 223 : sisimiut
# City Count 224 : varhaug
# City Count 225 : san luis
# City Count 226 : coquimbo
# City Count 227 : katsuura
# City not found! Skipping...
# City Count 228 : adrar
# City Count 229 : leshukonskoye
# City Count 230 : cayenne
# City Count 231 : kavieng
# City Count 232 : sampit
# City Count 233 : port-gentil
# City not found! Skipping...
# City Count 234 : dudinka
# City Count 235 : lompoc
# City Count 236 : fethiye
# City Count 237 : khuzhir
# City Count 238 : cedar city
# City Count 239 : tuatapere
# City Count 240 : klaksvik
# City Count 241 : bonavista
# City Count 242 : ixtapa
# City Count 243 : shieli
# City Count 244 : kloulklubed
# City Count 245 : alexandria
# City Count 246 : krasnoselkup
# City Count 247 : inyonga
# City Count 248 : wladyslawowo
# City not found! Skipping...
# City Count 249 : taoudenni
# City Count 250 : valleyview
# City Count 251 : praia da vitoria
# City Count 252 : north valley
# City Count 253 : tabuk
# City Count 254 : fort nelson
# City Count 255 : rudbar
# City Count 256 : godinesti
# City Count 257 : pakxan
# City Count 258 : gunjur
# City Count 259 : iguape
# City Count 260 : xichang
# City Count 261 : antalaha
# City Count 262 : wakkanai
# City Count 263 : kemijarvi
# City Count 264 : nur
# City Count 265 : doha
# City Count 266 : lujan
# City Count 267 : brae
# City Count 268 : mayo
# City Count 269 : udimskiy
# City Count 270 : ahuimanu
# City Count 271 : saga
# City Count 272 : san quintin
# City Count 273 : jacareacanga
# City not found! Skipping...
# City Count 274 : kavaratti
# City Count 275 : honningsvag
# City Count 276 : jutai
# City Count 277 : tasiilaq
# City Count 278 : gedo
# City Count 279 : vardo
# City Count 280 : ust-tarka
# City Count 281 : manutuke
# City not found! Skipping...
# City Count 282 : mehamn
# City Count 283 : novyy buyan
# City Count 284 : nouadhibou
# City Count 285 : khash
# City Count 286 : zuenoula
# City Count 287 : sukumo
# City Count 288 : skibbereen
# City Count 289 : miri
# City not found! Skipping...
# City Count 290 : tezu
# City Count 291 : basco
# City Count 292 : isangel
# City Count 293 : nanortalik
# City Count 294 : saint-pierre
# City Count 295 : general roca
# City Count 296 : zelenoborskiy
# City Count 297 : paamiut
# City Count 298 : aklavik
# City Count 299 : axim
# City not found! Skipping...
# City Count 300 : laguna
# City Count 301 : curup
# City Count 302 : sabang
# City Count 303 : sao filipe
# City Count 304 : severo-kurilsk
# City Count 305 : wilmington
# City Count 306 : port-cartier
# City Count 307 : luena
# City Count 308 : charagua
# City Count 309 : tiksi
# City Count 310 : yar-sale
# City Count 311 : zunyi
# City Count 312 : maridi
# City Count 313 : sibolga
# City Count 314 : kaeo
# City Count 315 : sangar
# City Count 316 : okhotsk
# City Count 317 : berlevag
# City not found! Skipping...
# City Count 318 : odweyne
# City not found! Skipping...
# City Count 319 : jurm
# City Count 320 : auki
# City Count 321 : severnoye
# City Count 322 : joshimath
# City Count 323 : cabangahan
# City Count 324 : french harbor
# City Count 325 : khatanga
# City Count 326 : mangai
# City not found! Skipping...
# City Count 327 : nhulunbuy
# City Count 328 : ochamchira
# City not found! Skipping...
# City Count 329 : banyo
# City Count 330 : gogrial
# City Count 331 : pontianak
# City Count 332 : burnie
# City not found! Skipping...
# City Count 333 : veinticinco de mayo
# City Count 334 : douglas
# City Count 335 : ilulissat
# City Count 336 : birao
# City Count 337 : ishigaki
# City Count 338 : gladstone
# City Count 339 : ust-kuyga
# City Count 340 : mgandu
# City Count 341 : hammerfest
# City Count 342 : farafangana
# City Count 343 : hokitika
# City Count 344 : srednekolymsk
# City Count 345 : partizanskoye
# City Count 346 : mae hong son
# City Count 347 : najran
# City Count 348 : ilhabela
# City Count 349 : pandan
# City Count 350 : lgov
# City Count 351 : albury
# City Count 352 : samarai
# City Count 353 : lukovetskiy
# City Count 354 : rawson
# City Count 355 : baghdad
# City Count 356 : fukuma
# City Count 357 : savalou
# City Count 358 : nishihara
# City Count 359 : severo-yeniseyskiy
# City Count 360 : champerico
# City Count 361 : severomuysk
# City Count 362 : vila franca do campo
# City Count 363 : ola
# City Count 364 : lavrentiya
# City Count 365 : broome
# City Count 366 : launceston
# City Count 367 : weligama
# City Count 368 : aswan
# City Count 369 : lata
# City Count 370 : ketchikan
# City not found! Skipping...
# City Count 371 : presidente prudente
# City Count 372 : shelburne
# City Count 373 : muros
# City Count 374 : mount gambier
# City Count 375 : qasigiannguit
# City Count 376 : itaqui
# City Count 377 : itupiranga
# City Count 378 : marienburg
# City Count 379 : avera
# City Count 380 : christchurch
# City Count 381 : dwarka
# City Count 382 : la ronge
# City Count 383 : hambantota
# City Count 384 : floro
# City Count 385 : choma
# City Count 386 : vao
# City Count 387 : borogontsy
# City Count 388 : montes altos
# City Count 389 : cam ranh
# City Count 390 : gbarnga
# City Count 391 : sur
# City Count 392 : inhambane
# City Count 393 : hualmay
# City Count 394 : shakawe
# City Count 395 : clyde river
# City Count 396 : marsh harbour
# City Count 397 : viedma
# City Count 398 : haicheng
# City Count 399 : makat
# City Count 400 : marawi
# City Count 401 : kyabram
# City Count 402 : lufilufi
# City Count 403 : pundaguitan
# City Count 404 : babati
# City Count 405 : medicine hat
# City Count 406 : henties bay
# City Count 407 : tigil
# City Count 408 : ahipara
# City Count 409 : belaya gora
# City Count 410 : kavarskas
# City Count 411 : daru
# City Count 412 : sitka
# City Count 413 : misratah
# City Count 414 : bereda
# City Count 415 : minab
# City Count 416 : praia
# City Count 417 : sao sebastiao
# City Count 418 : carauari
# City Count 419 : madimba
# City Count 420 : buraydah
# City Count 421 : yarkovo
# City Count 422 : fukue
# City Count 423 : mandalgovi
# City Count 424 : nichinan
# City Count 425 : kulhudhuffushi
# City not found! Skipping...
# City Count 426 : atar
# City Count 427 : padang
# City Count 428 : necochea
# City Count 429 : araria
# City not found! Skipping...
# City Count 430 : salalah
# City Count 431 : helong
# City Count 432 : bengkulu
# City Count 433 : evensk
# City Count 434 : jedburgh
# City Count 435 : natchitoches
# City Count 436 : bandar
# City not found! Skipping...
# City Count 437 : narayanpet
# City Count 438 : bandarbeyla
# City Count 439 : kitimat
# City Count 440 : waingapu
# City Count 441 : nezhinka
# City Count 442 : husavik
# City Count 443 : morlaix
# City Count 444 : pyaozerskiy
# City Count 445 : grindavik
# City Count 446 : mazyr
# City Count 447 : prince rupert
# City Count 448 : zhangjiakou
# City Count 449 : piracanjuba
# City Count 450 : jalu
# City Count 451 : arona
# City not found! Skipping...
# City Count 452 : alanya
# City Count 453 : malindi
# City Count 454 : westport
# City Count 455 : soe
# City Count 456 : jizan
# City Count 457 : mwinilunga
# City not found! Skipping...
# City Count 458 : deputatskiy
# City Count 459 : bilibino
# City Count 460 : benicarlo
# City Count 461 : margate
# City Count 462 : tomatlan
# City Count 463 : chilliwack
# City Count 464 : rio gallegos
# City Count 465 : rock sound
# City not found! Skipping...
# City Count 466 : north bend
# City Count 467 : hargeysa
# City Count 468 : homer
# City Count 469 : motihari
# City Count 470 : kambove
# City Count 471 : boyolangu
# City Count 472 : manakara
# City Count 473 : bystryy istok
# City Count 474 : tautira
# City Count 475 : verkhoyansk
# City Count 476 : qazvin
# City Count 477 : mantua
# City Count 478 : hamilton
# City Count 479 : san rafael del sur
# City Count 480 : yerbogachen
# City not found! Skipping...
# City Count 481 : pouembout
# City Count 482 : killarney
# City Count 483 : yatou
# City Count 484 : luanda
# City Count 485 : serenje
# City Count 486 : haverfordwest
# City not found! Skipping...
# City Count 487 : gualeguaychu
# City Count 488 : veracruz
# City Count 489 : colac
# City Count 490 : kaitangata
# City Count 491 : vestmanna
# City Count 492 : darhan
# City Count 493 : todos santos
# City Count 494 : novoomskiy
# City Count 495 : laramie
# City Count 496 : kyren
# City Count 497 : verkhnyaya inta
# City Count 498 : idrinskoye
# City Count 499 : nushki
# City Count 500 : port lincoln
# City Count 501 : havre-saint-pierre
# City not found! Skipping...
# City Count 502 : esperance
# City Count 503 : hervey bay
# City Count 504 : nioro
# City Count 505 : nemuro
# City Count 506 : lodja
# City Count 507 : alamogordo
# City Count 508 : areni
# City Count 509 : kieta
# City Count 510 : shunyi
# City Count 511 : hobyo
# City Count 512 : bathsheba
# City Count 513 : faanui
# City Count 514 : araouane
# City Count 515 : karonga
# City Count 516 : traverse city
# City Count 517 : massakory
# City Count 518 : grants
# City Count 519 : santa isabel do rio negro
# City Count 520 : yeppoon
# City Count 521 : bosaso
# City Count 522 : kant
# City Count 523 : cockburn town
# City Count 524 : kourou
# City Count 525 : beruwala
# City Count 526 : soyo
# City Count 527 : green river
# City Count 528 : turbat
# City Count 529 : sanivarsante
# City Count 530 : kununurra
# City Count 531 : truth or consequences
# City Count 532 : ndele
# City Count 533 : tecoanapa
# City Count 534 : hay river
# City Count 535 : iracoubo
# City Count 536 : cody
# City Count 537 : saurimo
# City Count 538 : campo verde
# City Count 539 : saint-augustin
# City Count 540 : katima mulilo
# City Count 541 : visnes
# City Count 542 : hailey
# City Count 543 : hovd
# City Count 544 : puerto suarez
# City Count 545 : mongo
# City Count 546 : kharp
# City Count 547 : qui nhon
# City Count 548 : madingou
# City Count 549 : macas
# City Count 550 : mnogovershinnyy
# City Count 551 : goderich
# City not found! Skipping...
# City Count 552 : wuzhou
# City Count 553 : rincon
# City Count 554 : vanimo
# City Count 555 : humberto de campos
# City Count 556 : shanhetun
# City Count 557 : the pas
# City Count 558 : maues
# City Count 559 : police
# City Count 560 : itajuipe
# City Count 561 : redcliffe
# City Count 562 : yumaguzino
# City not found! Skipping...
# City Count 563 : bonawon
# City Count 564 : namtsy
# City Count 565 : kontagora
# City Count 566 : santa maria
# City Count 567 : torrelavega
# City Count 568 : asfi
# City Count 569 : bilma
# City Count 570 : sakakah
# City Count 571 : tiarei
# City Count 572 : chimoio
# City Count 573 : bambanglipuro
# City Count 574 : itarema
# City Count 575 : port hardy
# City Count 576 : kirovskiy
# City not found! Skipping...
# City Count 577 : shaunavon
# City Count 578 : aden
# City Count 579 : selaphum
# City Count 580 : turochak
# City Count 581 : tingi
# City not found! Skipping...
# City Count 582 : nelson bay
# City Count 583 : sembe
# -----------------------
# Data Retrieval Complete
# 584 Records Found
# -----------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_weather_data_df = pd.DataFrame({"City":name,
                                     "Country":country,
                                     "Latitude":lat,
                                     "Longitude":long,
                                     "Date":date,
                                     "Temperature (F)": temp,
                                     "Temp Max":temp_max,
                                     "Humidity (%)":humidity,
                                     "Cloudiness (%)":cloudy,
                                     "Windspeed (mph)":windspeed})
city_weather_data_df.to_csv(output_data)
city_weather_data_df
# Out:
#             City Country  Latitude  Longitude        Date  Temperature (F)  \
# 0       Jennings      US     38.72     -90.26  1600208260            78.69
# 1          Bluff      NZ    -46.60     168.33  1600208086            48.99
# 2          Kapaa      US     22.08    -159.32  1600208097            84.79
# 3           Lebu      CL    -37.62     -73.65  1600208260            50.95
# 4    Grand-Santi      GF      4.25     -54.38  1600208260            75.85
# ..           ...     ...       ...        ...         ...              ...
# 579     Selaphum      TH     16.03     103.94  1600208316            77.11
# 580     Turochak      RU     52.26      87.12  1600208316            47.59
# 581        Tingi      TZ    -11.30      35.03  1600208316            68.38
# 582   Nelson Bay      AU    -32.72     152.15  1600207872            59.63
# 583        Sémbé      CG      1.65      14.58  1600208254            71.13
#
#      Temp Max  Humidity (%)  Cloudiness (%)  Windspeed (mph)
# 0       81.00            44              75             5.82
# 1       48.99            79             100            14.00
# 2       86.00            58              20            10.29
# 3       50.95            96             100             6.06
# 4       75.85            90              81             0.54
# ..        ...           ...             ...              ...
# 579     77.11            85              77             2.42
# 580     47.59            80              82             3.53
# 581     68.38            52              31             6.89
# 582     60.01            93              20             5.82
# 583     71.13            93              57             1.86
#
# [584 rows x 10 columns]

# %%
#check data all values have data and new count for 'cities found'
city_weather_data_df.count()
# Out:
# City               584
# Country            584
# Latitude           584
# Longitude          584
# Date               584
# Temperature (F)    584
# Temp Max           584
# Humidity (%)       584
# Cloudiness (%)     584
# Windspeed (mph)    584
# dtype: int64

# %%
city_weather_data_df.describe()
# Out:
#          Latitude   Longitude          Date  Temperature (F)    Temp Max  \
# count  584.000000  584.000000  5.840000e+02       584.000000  584.000000
# mean    18.697757   21.298801  1.600208e+09        65.574863   65.927243
# std     33.671235   90.622828  1.651853e+02        15.188243   15.289683
# min    -54.800000 -179.170000  1.600208e+09        19.980000   19.980000
# 25%     -8.967500  -56.250000  1.600208e+09        52.667500   52.960000
# 50%     19.530000   25.060000  1.600208e+09        67.405000   68.000000
# 75%     48.585000  102.812500  1.600208e+09        77.752500   78.197500
# max     78.220000  179.320000  1.600208e+09       104.180000  104.180000
#
#        Humidity (%)  Cloudiness (%)  Windspeed (mph)
# count    584.000000      584.000000       584.000000
# mean      72.212329       55.273973         7.721353
# std       21.491698       37.337048         5.586533
# min        7.000000        0.000000         0.090000
# 25%       61.750000       20.000000         3.360000
# 50%       78.000000       63.000000         6.710000
# 75%       88.000000       91.000000        10.327500
# max      100.000000      100.000000        33.330000

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#create scatter plot latitude vs max temp
plt.scatter(city_weather_data_df['Latitude'], city_weather_data_df['Temp Max'], marker="o", edgecolors="black")
plt.title("Latitude of Cities vs. Max Temperature on 15Sep2020")
plt.xlabel("Latitude of Cities")
plt.ylabel("Max Temperature (F)")
plt.grid()
plt.savefig("Images/scatter_lat_vs_maxtemp.png")
plt.show()

# %%
print(f'Scatter plot of latitude versus max temperature. Max temp gets highest closest to the equator')
# Out:
# Scatter plot of latitude versus max temperature. Max temp gets highest closest to the equator

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#create scatter plot latitude vs humidity
plt.scatter(city_weather_data_df['Latitude'], city_weather_data_df['Humidity (%)'], marker="o", edgecolors="black")
plt.title("Latitude of Cities vs. Humidity on 15Sep2020")
plt.xlabel("Latitude of Cities")
plt.ylabel("Humidity %")
plt.grid()
plt.savefig("Images/scatter_lat_vs_humidity.png")
plt.show()

# %%
print(f'Scatter plot of latitude versus humidity. Humidity correlations indiscernible')
# Out:
# Scatter plot of latitude versus humidity. Humidity correlations indiscernible

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
#create scatter plot latitude vs cloudiness
plt.scatter(city_weather_data_df['Latitude'], city_weather_data_df['Cloudiness (%)'], marker="o", edgecolors="black")
plt.title("Latitude of Cities vs. Cloudiness on 15Sep2020")
plt.xlabel("Latitude of Cities")
plt.ylabel("Cloudiness %")
plt.grid()
plt.savefig("Images/scatter_lat_vs_cloudiness.png")
plt.show()

# %%
print(f'Scatter plot of latitude versus cloudiness. Cloudiness correlations indiscernible')
# Out:
# Scatter plot of latitude versus cloudiness. Cloudiness correlations indiscernible

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
#create scatter plot latitude vs wind speed
plt.scatter(city_weather_data_df['Latitude'], city_weather_data_df['Windspeed (mph)'], marker="o", edgecolors="black")
plt.title("Latitude of Cities vs. Wind Speed on 15Sep2020")
plt.xlabel("Latitude of Cities")
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.savefig("Images/scatter_lat_vs_windspeed.png")
plt.show()

# %%
print(f'Scatter plot of latitude versus wind speed. Wind speed correlations indiscernible')
# Out:
# Scatter plot of latitude versus wind speed. Wind speed correlations indiscernible

# %% [markdown]
# ## Linear Regression

# %%
north_weather_df = city_weather_data_df.loc[city_weather_data_df["Latitude"] >= 0]
north_weather_df
# Out:
#              City Country  Latitude  Longitude        Date  Temperature (F)  \
# 0        Jennings      US     38.72     -90.26  1600208260            78.69
# 2           Kapaa      US     22.08    -159.32  1600208097            84.79
# 4     Grand-Santi      GF      4.25     -54.38  1600208260            75.85
# 6    Staryy Nadym      RU     65.61      72.68  1600208261            50.23
# 8          Norden      DE     53.60       7.20  1600208261            65.16
# ..            ...     ...       ...        ...         ...              ...
# 577     Shaunavon      CA     49.65    -108.42  1600208303            65.39
# 578          Aden      YE     12.78      45.04  1600208060            90.18
# 579      Selaphum      TH     16.03     103.94  1600208316            77.11
# 580      Turochak      RU     52.26      87.12  1600208316            47.59
# 583         Sémbé      CG      1.65      14.58  1600208254            71.13
#
#      Temp Max  Humidity (%)  Cloudiness (%)  Windspeed (mph)
# 0       81.00            44              75             5.82
# 2       86.00            58              20            10.29
# 4       75.85            90              81             0.54
# 6       50.23            89             100            10.49
# 8       66.00            93              79             1.12
# ..        ...           ...             ...              ...
# 577     65.39            34              46            14.94
# 578     90.18            64              28             1.32
# 579     77.11            85              77             2.42
# 580     47.59            80              82             3.53
# 583     71.13            93              57             1.86
#
# [389 rows x 10 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#locate all data >=0 latitude in new df
north_weather_df = city_weather_data_df.loc[city_weather_data_df["Latitude"] >= 0]
north_weather_df
x_values = north_weather_df['Latitude']
y_values = north_weather_df['Temp Max']
#create scatter plot northern latitudes vs max temp
plt.scatter(x_values, y_values, marker="o", edgecolors="black")
plt.title("Latitude of Cities in Northern Hemisphere vs. Max Temperature on 15Sep2020")
plt.xlabel("Latitude of Cities")
plt.ylabel("Max Temperature (F)")
plt.grid()
#regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
r_squared = rvalue**2
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,100),fontsize=12,color="red")

#save & show
plt.savefig("Images/scatter_NORTH_lat_vs_maxtemp_regression.png")
plt.show()
print(f"The r-squared is: {r_squared}")
# Out:
# The r-squared is: 0.6450520216143475

# %%
print(f' There appears to be a decent correlation between increasing latitude and lower temperatures')
# Out:
#  There appears to be a decent correlation between increasing latitude and lower temperatures

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
south_weather_df = city_weather_data_df.loc[city_weather_data_df["Latitude"] < 0]
south_weather_df
x_values = south_weather_df['Latitude']
y_values = south_weather_df['Temp Max']
#create scatter plot southern latitudes vs max temp
plt.scatter(south_weather_df['Latitude'], south_weather_df['Temp Max'], marker="o", edgecolors="black")
plt.title("Latitude of Cities in Southern Hemisphere vs. Max Temperature on 15Sep2020")
plt.xlabel("Latitude of Cities")
plt.ylabel("Max Temperature (F)")
plt.grid()

#regression 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
r_squared = rvalue**2
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,45),fontsize=12,color="red")

#save & show
plt.savefig("Images/scatter_SOUTH_lat_vs_maxtemp_regression.png")
plt.show()
print(f"The r-squared is: {r_squared}")
# Out:
# The r-squared is: 0.6305655427884524

# %%
print(f' There appears to be a decent correlation between temperatures being higher closer to the equator')
# Out:
#  There appears to be a decent correlation between temperatures being higher closer to the equator

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#set x & y values
x_values = north_weather_df['Latitude']
y_values = north_weather_df['Humidity (%)']
#create scatter plot northern latitudes vs max temp
plt.scatter(x_values, y_values, marker="o", edgecolors="black")
plt.title("Latitude of Cities in Northern Hemisphere vs. Humidity (%) on 15Sep2020")
plt.xlabel("Latitude of Cities")
plt.ylabel("Humidity (%)")
plt.grid()
#regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
r_squared = rvalue**2
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50,20),fontsize=12,color="red")

#save & show
plt.savefig("Images/scatter_NORTH_lat_vs_humidity_regression.png")
plt.show()
print(f"The r-squared is: {r_squared}")
# Out:
# The r-squared is: 0.005609023930592941

# %%
print(f'There appears no be no correlation between northern latitude and humidity')
# Out:
# There appears no be no correlation between northern latitude and humidity

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#set x & y values
x_values = south_weather_df['Latitude']
y_values = south_weather_df['Humidity (%)']
#create scatter plot southern latitudes vs max temp
plt.scatter(x_values, y_values, marker="o", edgecolors="black")
plt.title("Latitude of Cities in Southern Hemisphere vs. Humidity (%) on 15Sep2020")
plt.xlabel("Latitude of Cities")
plt.ylabel("Humidity (%)")
plt.grid()

#regression 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
r_squared = rvalue**2
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50, 50),fontsize=12,color="red")

#save & show
plt.savefig("Images/scatter_SOUTH_lat_vs_humidity_regression.png")
plt.show()
print(f"The r-squared is: {r_squared}")
# Out:
# The r-squared is: 0.009513462429077307

# %%
print(f'There appears no be no correlation between southern latitude and humidity')
# Out:
# There appears no be no correlation between southern latitude and humidity

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#set x & y values
x_values = north_weather_df['Latitude']
y_values = north_weather_df['Cloudiness (%)']
#create scatter plot northern latitudes vs max temp
plt.scatter(x_values, y_values, marker="o", edgecolors="black")
plt.title("Latitude of Cities in Northern Hemisphere vs. Cloudiness (%) on 15Sep2020")
plt.xlabel("Latitude of Cities")
plt.ylabel("Cloudiness (%)")
plt.grid()
#regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
r_squared = rvalue**2
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(12,30),fontsize=10,color="red")

#save & show
plt.savefig("Images/scatter_NORTH_lat_vs_cloudiness_regression.png")
plt.show()
print(f"The r-squared is: {r_squared}")
# Out:
# The r-squared is: 0.00390854490528666

# %%
print(f'There appears no be no correlation between northern latitude and cloudiness')
# Out:
# There appears no be no correlation between northern latitude and cloudiness

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#set x & y values
x_values = south_weather_df['Latitude']
y_values = south_weather_df['Cloudiness (%)']
#create scatter plot southern latitudes vs max temp
plt.scatter(x_values, y_values, marker="o", edgecolors="black")
plt.title("Latitude of Cities in Southern Hemisphere vs. Cloudiness (%) on 15Sep2020")
plt.xlabel("Latitude of Cities")
plt.ylabel("Cloudiness (%)")
plt.grid()

#regression 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
r_squared = rvalue**2
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55, 60),fontsize=12,color="red")

#save & show
plt.savefig("Images/scatter_SOUTH_lat_vs_cloudiness_regression.png")
plt.show()
print(f"The r-squared is: {r_squared}")
# Out:
# The r-squared is: 0.0002221629151779559

# %%
print(f'There appears no be no correlation between southern latitude and cloudiness')
# Out:
# There appears no be no correlation between southern latitude and cloudiness

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#set x & y values
x_values = north_weather_df['Latitude']
y_values = north_weather_df['Windspeed (mph)']
#create scatter plot northern latitudes vs max temp
plt.scatter(x_values, y_values, marker="o", edgecolors="black")
plt.title("Latitude of Cities in Northern Hemisphere vs. Windspeed on 15Sep2020")
plt.xlabel("Latitude of Cities")
plt.ylabel("Windspeed (mph)")
plt.grid()
#regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
r_squared = rvalue**2
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(10,25),fontsize=12,color="red")

#save & show
plt.savefig("Images/scatter_NORTH_lat_vs_windspeed_regression.png")
plt.show()
print(f"The r-squared is: {r_squared}")
# Out:
# The r-squared is: 0.006947461225797813

# %%
print(f'There appears no be no correlation between northern latitude and wind speed')
# Out:
# There appears no be no correlation between northern latitude and wind speed

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#set x & y values
x_values = south_weather_df['Latitude']
y_values = south_weather_df['Windspeed (mph)']
#create scatter plot southern latitudes vs max temp
plt.scatter(x_values, y_values, marker="o", edgecolors="black")
plt.title("Latitude of Cities in Southern Hemisphere vs. Windspeed on 15Sep2020")
plt.xlabel("Latitude of Cities")
plt.ylabel("Windspeed (mph)")
plt.grid()

#regression 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
r_squared = rvalue**2
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55, 11),fontsize=10,color="red")

#save & show
plt.savefig("Images/scatter_SOUTH_lat_vs_windspeed_regression.png")
plt.show()
print(f"The r-squared is: {r_squared}")
# Out:
# The r-squared is: 0.06562260172168186

# %%
print(f'There appears no be no correlation between southern latitude and wind speed')
# Out:
# There appears no be no correlation between southern latitude and wind speed
