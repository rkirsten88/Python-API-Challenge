# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import scipy.stats as st
from scipy.stats import linregress

# Import API key
from config import api_key

temp_units = "imperial"

#citipy to determine lat/long
from citipy import citipy

lat_range= (-90, 90)
long_range = (-180, 180)

url = "http://api.openweathermap.org/data/2.5/weather?"
query_url = f"{url}appid={api_key}&units={temp_units}&q="
output_data = "Output/city_data.csv"

# %% [markdown]
# ## Generate Cities List

# %%
#empty list for holding lat/long and city names
lats_longs = []
city_names = []

#create random set of lat/longs
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
longs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lats_longs = zip(lats, longs)

#loop through lats_longs to find coordinates using citipy and add unique names to list
for coordinates in lats_longs:
    city_name = citipy.nearest_city(coordinates[0], coordinates[1]).city_name

    if city_name not in city_names:
        city_names.append(city_name)
    
city_count = len(city_names)
print(city_count)
# Out:
# 648

# %%
#weather_response_json = requests.get(query_url + city_name).json()
#print(json.dumps(weather_response_json, sort_keys=True, indent=2))

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Starting URL for Weather Map API Call
query_url = f"{url}appid={api_key}&units={temp_units}&q="

#create new lists for city data
lat = []
long = []
temp = []
temp_max = []
humidity = [] 
cloudy = []
windspeed = []
name = []
country = []
date = []
#set count for timer
#counter = 0
#maxattempts = 59
#set record counter starting with 1
processing_record = 1

# for loop to determine data for new lists with try/except    
for city in city_names:    
    try:
        response = requests.get(query_url + city).json()
        lat.append(response['coord']['lat'])
        long.append(response['coord']['lon'])
        temp.append(response['main']['temp'])
        temp_max.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudy.append(response['clouds']['all'])
        windspeed.append(response['wind']['speed'])
        name.append(response['name'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        print(f"City Count {processing_record} : {city}")
        #counter += 1        
        processing_record += 1
    except:
        #print log
        print("City not found! Skipping...")
        #pass
    #if counter == maxattempts:
        #time.sleep(60)
        #counter = 0

              
print(f"-----------------------")
print(f"Data Retrieval Complete")
print(f"-----------------------")

#print results
print(f"latitude: {lat} {len(lat)}")
print(f"longitude: {long} {len(long)}")
print(f"temperature: {temp} {len(temp)}")
print(f"temp_max: {temp_max} {len(temp_max)}")
print(f"humidity: {humidity} {len(humidity)}")
print(f"clouds: {cloudy} {len(cloudy)}")
print(f"wind speed: {windspeed} {len(windspeed)}")
print(f"date: {date} {len(date)}")
print(f"city name: {name} {len(name)}")
# Out:
# City Count 1 : los llanos de aridane
# City Count 2 : tuktoyaktuk
# City Count 3 : maguling
# City Count 4 : hualmay
# City not found! Skipping...
# City Count 5 : jamestown
# City Count 6 : kodiak
# City Count 7 : arraial do cabo
# City Count 8 : carnarvon
# City Count 9 : hilo
# City Count 10 : margate
# City Count 11 : ueda
# City Count 12 : cidreira
# City Count 13 : njombe
# City Count 14 : ryotsu
# City Count 15 : gamba
# City Count 16 : longyearbyen
# City Count 17 : mahon
# City Count 18 : varzea grande
# City Count 19 : ambovombe
# City not found! Skipping...
# City Count 20 : lagoa
# City Count 21 : east london
# City Count 22 : kenai
# City not found! Skipping...
# City Count 23 : beringovskiy
# City Count 24 : nanortalik
# City Count 25 : codrington
# City Count 26 : mataura
# City Count 27 : minyar
# City Count 28 : kloulklubed
# City Count 29 : barrow
# City Count 30 : mollendo
# City Count 31 : georgetown
# City not found! Skipping...
# City Count 32 : broome
# City Count 33 : ronne
# City Count 34 : hami
# City Count 35 : punta arenas
# City Count 36 : cabedelo
# City not found! Skipping...
# City Count 37 : pavilosta
# City Count 38 : hermanus
# City Count 39 : coro
# City Count 40 : lazaro cardenas
# City Count 41 : biltine
# City Count 42 : belaya gora
# City Count 43 : resen
# City Count 44 : chadiza
# City Count 45 : teya
# City Count 46 : kruisfontein
# City Count 47 : rikitea
# City Count 48 : soyo
# City Count 49 : victoria
# City not found! Skipping...
# City Count 50 : mahebourg
# City Count 51 : kouroussa
# City Count 52 : ushuaia
# City Count 53 : alta floresta
# City Count 54 : chokurdakh
# City not found! Skipping...
# City Count 55 : egvekinot
# City Count 56 : san joaquin
# City Count 57 : kysyl-syr
# City Count 58 : saint-philippe
# City Count 59 : vallenar
# City Count 60 : busselton
# City Count 61 : tiksi
# City Count 62 : roald
# City Count 63 : souillac
# City not found! Skipping...
# City Count 64 : ancud
# City Count 65 : airai
# City Count 66 : faanui
# City Count 67 : foz
# City Count 68 : atuona
# City Count 69 : qaanaaq
# City Count 70 : hithadhoo
# City not found! Skipping...
# City Count 71 : ahipara
# City Count 72 : port alfred
# City Count 73 : lai
# City Count 74 : jinxiang
# City Count 75 : cayenne
# City Count 76 : balikpapan
# City Count 77 : kapaa
# City Count 78 : hobart
# City Count 79 : chapais
# City not found! Skipping...
# City Count 80 : ornskoldsvik
# City Count 81 : haines junction
# City Count 82 : muros
# City Count 83 : mar del plata
# City Count 84 : pathein
# City not found! Skipping...
# City Count 85 : butaritari
# City Count 86 : avarua
# City not found! Skipping...
# City Count 87 : dikson
# City Count 88 : luderitz
# City Count 89 : diu
# City Count 90 : gat
# City Count 91 : meulaboh
# City Count 92 : boa vista
# City Count 93 : bathsheba
# City Count 94 : hovd
# City Count 95 : namibe
# City Count 96 : sunrise manor
# City Count 97 : ribeira grande
# City Count 98 : tasiilaq
# City Count 99 : santa maria do suacui
# City Count 100 : mugan
# City Count 101 : honiara
# City Count 102 : las margaritas
# City Count 103 : castro
# City not found! Skipping...
# City Count 104 : lompoc
# City Count 105 : abu dhabi
# City Count 106 : peterhead
# City Count 107 : olafsvik
# City Count 108 : nisia floresta
# City Count 109 : ginda
# City Count 110 : dingle
# City Count 111 : sandnessjoen
# City Count 112 : saint-lo
# City Count 113 : port elizabeth
# City Count 114 : narsaq
# City Count 115 : novyy oskol
# City Count 116 : chuy
# City not found! Skipping...
# City Count 117 : puerto narino
# City not found! Skipping...
# City Count 118 : laguna
# City Count 119 : bjerringbro
# City not found! Skipping...
# City Count 120 : quatre cocos
# City Count 121 : aksarka
# City Count 122 : college
# City not found! Skipping...
# City Count 123 : ambunti
# City Count 124 : zaraza
# City Count 125 : saint-joseph
# City Count 126 : bluff
# City Count 127 : albany
# City Count 128 : tagusao
# City Count 129 : fairbanks
# City Count 130 : khatanga
# City Count 131 : mwinilunga
# City Count 132 : new norfolk
# City Count 133 : trofors
# City Count 134 : emirdag
# City Count 135 : stromness
# City Count 136 : bereda
# City Count 137 : bambous virieux
# City Count 138 : jacareacanga
# City Count 139 : mount pleasant
# City Count 140 : severo-kurilsk
# City Count 141 : emerald
# City Count 142 : birao
# City not found! Skipping...
# City Count 143 : umm lajj
# City Count 144 : dwarka
# City Count 145 : ribeirao bonito
# City Count 146 : lata
# City Count 147 : norman wells
# City Count 148 : provideniya
# City Count 149 : nianzishan
# City Count 150 : kerrville
# City Count 151 : grand gaube
# City Count 152 : atagay
# City Count 153 : guozhen
# City Count 154 : nikolskoye
# City Count 155 : sitka
# City Count 156 : yamada
# City Count 157 : amur
# City Count 158 : ilulissat
# City Count 159 : takoradi
# City Count 160 : upernavik
# City not found! Skipping...
# City Count 161 : kavaratti
# City Count 162 : havelock
# City not found! Skipping...
# City Count 163 : homer
# City Count 164 : damietta
# City Count 165 : winnemucca
# City Count 166 : vaini
# City Count 167 : porosozero
# City Count 168 : poum
# City Count 169 : port hardy
# City Count 170 : saint-francois
# City Count 171 : orlik
# City Count 172 : tromso
# City Count 173 : kirakira
# City Count 174 : ikom
# City Count 175 : anadyr
# City Count 176 : geraldton
# City not found! Skipping...
# City Count 177 : vila franca do campo
# City Count 178 : cabatuan
# City not found! Skipping...
# City Count 179 : la orilla
# City Count 180 : selishche
# City not found! Skipping...
# City Count 181 : komsomolskiy
# City Count 182 : isangel
# City Count 183 : flin flon
# City Count 184 : kangaatsiaq
# City Count 185 : tecoanapa
# City Count 186 : novyy svit
# City Count 187 : bakchar
# City Count 188 : kaitangata
# City Count 189 : naze
# City Count 190 : nuuk
# City Count 191 : povenets
# City Count 192 : yellowknife
# City Count 193 : bredasdorp
# City not found! Skipping...
# City Count 194 : genc
# City Count 195 : moshupa
# City Count 196 : cape town
# City Count 197 : halifax
# City Count 198 : livingston
# City Count 199 : constantine
# City Count 200 : rafaela
# City Count 201 : bethanien
# City Count 202 : talnakh
# City Count 203 : ponta do sol
# City Count 204 : silifke
# City Count 205 : leningradskiy
# City Count 206 : alice town
# City Count 207 : khani
# City Count 208 : calatayud
# City Count 209 : morondava
# City Count 210 : shenjiamen
# City Count 211 : wanning
# City Count 212 : aragarcas
# City Count 213 : arti
# City Count 214 : doka
# City Count 215 : xingtai
# City Count 216 : landau
# City Count 217 : bonfim
# City Count 218 : alofi
# City Count 219 : henties bay
# City Count 220 : biak
# City Count 221 : basco
# City Count 222 : kazanskoye
# City Count 223 : flinders
# City Count 224 : petropavl
# City Count 225 : andros town
# City Count 226 : la paz
# City Count 227 : puerto ayora
# City Count 228 : moose jaw
# City Count 229 : pio xii
# City Count 230 : ust-ilimsk
# City Count 231 : biu
# City Count 232 : araouane
# City Count 233 : elizabeth city
# City not found! Skipping...
# City Count 234 : ukiah
# City Count 235 : banjarmasin
# City Count 236 : xining
# City Count 237 : kahului
# City Count 238 : kavieng
# City Count 239 : miraflores
# City not found! Skipping...
# City Count 240 : yerbogachen
# City not found! Skipping...
# City Count 241 : kelvington
# City Count 242 : tigil
# City Count 243 : avera
# City not found! Skipping...
# City Count 244 : camacupa
# City Count 245 : san patricio
# City Count 246 : sabang
# City Count 247 : alice springs
# City Count 248 : westport
# City Count 249 : vorotynets
# City not found! Skipping...
# City Count 250 : port-gentil
# City Count 251 : lebu
# City Count 252 : chimbote
# City Count 253 : veraval
# City Count 254 : rawson
# City Count 255 : baykit
# City Count 256 : moen
# City Count 257 : cabo san lucas
# City not found! Skipping...
# City Count 258 : chifeng
# City Count 259 : cherskiy
# City not found! Skipping...
# City Count 260 : mersing
# City Count 261 : labuhan
# City not found! Skipping...
# City not found! Skipping...
# City Count 262 : okhotsk
# City Count 263 : ranong
# City Count 264 : faya
# City Count 265 : argelia
# City Count 266 : sao sebastiao
# City Count 267 : shyryayeve
# City not found! Skipping...
# City Count 268 : constitucion
# City Count 269 : teberda
# City Count 270 : tupik
# City Count 271 : lavrentiya
# City Count 272 : san quintin
# City Count 273 : saskylakh
# City Count 274 : salalah
# City Count 275 : aleksandrov gay
# City Count 276 : colorines
# City Count 277 : terrace
# City Count 278 : acapulco
# City Count 279 : tilichiki
# City Count 280 : ambilobe
# City Count 281 : preili
# City Count 282 : campo grande
# City Count 283 : chardara
# City Count 284 : hofn
# City Count 285 : hambantota
# City Count 286 : kitob
# City Count 287 : blagoyevo
# City Count 288 : novobelokatay
# City Count 289 : awbari
# City not found! Skipping...
# City Count 290 : singaparna
# City Count 291 : kaniama
# City Count 292 : marawi
# City Count 293 : znamenskoye
# City Count 294 : thompson
# City Count 295 : bansang
# City Count 296 : la ronge
# City Count 297 : sur
# City Count 298 : beeville
# City Count 299 : nemuro
# City Count 300 : saquisili
# City Count 301 : hargeysa
# City Count 302 : lleida
# City Count 303 : uvinza
# City Count 304 : nadbai
# City Count 305 : cabinda
# City Count 306 : perth
# City Count 307 : zaragoza
# City Count 308 : astana
# City Count 309 : bitung
# City Count 310 : kibala
# City Count 311 : erzin
# City Count 312 : ambon
# City not found! Skipping...
# City Count 313 : cairns
# City Count 314 : rincon
# City Count 315 : zapadnaya dvina
# City Count 316 : gombong
# City Count 317 : santa maria
# City Count 318 : bethel
# City Count 319 : taldan
# City Count 320 : padang
# City Count 321 : clyde river
# City Count 322 : grindavik
# City Count 323 : nhulunbuy
# City Count 324 : port blair
# City Count 325 : las vegas
# City Count 326 : kyaikkami
# City Count 327 : gerash
# City Count 328 : shingu
# City Count 329 : bandundu
# City Count 330 : nicoya
# City Count 331 : chumphon
# City Count 332 : kunyang
# City Count 333 : samoded
# City Count 334 : raudeberg
# City Count 335 : iqaluit
# City Count 336 : dunedin
# City Count 337 : les cayes
# City Count 338 : kampot
# City Count 339 : kudahuvadhoo
# City Count 340 : hervey bay
# City Count 341 : arlit
# City Count 342 : tumaco
# City Count 343 : sao joao da barra
# City Count 344 : ostrovnoy
# City Count 345 : alberton
# City Count 346 : caravelas
# City Count 347 : parabel
# City Count 348 : vereshchagino
# City Count 349 : katsuura
# City Count 350 : jimenez
# City Count 351 : houlton
# City Count 352 : venustiano carranza
# City Count 353 : kyzyl-suu
# City Count 354 : ketchikan
# City Count 355 : manzhouli
# City Count 356 : baturaja
# City Count 357 : comodoro rivadavia
# City Count 358 : caraquet
# City Count 359 : saint-leu
# City Count 360 : mount gambier
# City Count 361 : romny
# City Count 362 : severnyy
# City not found! Skipping...
# City Count 363 : yulara
# City Count 364 : mizdah
# City Count 365 : tevaitoa
# City Count 366 : guerrero negro
# City Count 367 : general roca
# City not found! Skipping...
# City Count 368 : sola
# City Count 369 : merzifon
# City Count 370 : kita
# City Count 371 : kefamenanu
# City Count 372 : saint-louis
# City Count 373 : slonim
# City Count 374 : presidente olegario
# City Count 375 : saint anthony
# City Count 376 : vao
# City Count 377 : tukrah
# City Count 378 : rodrigues alves
# City Count 379 : devonport
# City Count 380 : taltal
# City Count 381 : nanakuli
# City Count 382 : klaksvik
# City Count 383 : opuwo
# City Count 384 : mnogovershinnyy
# City Count 385 : qidong
# City Count 386 : mbanza-ngungu
# City Count 387 : watertown
# City Count 388 : lasa
# City not found! Skipping...
# City Count 389 : camana
# City Count 390 : yumen
# City Count 391 : ordynskoye
# City Count 392 : saint-augustin
# City Count 393 : yakima
# City Count 394 : okha
# City Count 395 : yumbe
# City not found! Skipping...
# City Count 396 : nusaybin
# City Count 397 : tamandare
# City Count 398 : wairoa
# City Count 399 : arman
# City Count 400 : vila velha
# City Count 401 : ventspils
# City not found! Skipping...
# City Count 402 : balabac
# City Count 403 : fallon
# City Count 404 : russell
# City Count 405 : muscat
# City Count 406 : staryy nadym
# City Count 407 : pevek
# City Count 408 : awjilah
# City Count 409 : la maddalena
# City Count 410 : karratha
# City Count 411 : domoszlo
# City not found! Skipping...
# City Count 412 : nalut
# City Count 413 : ossora
# City Count 414 : owando
# City Count 415 : camopi
# City Count 416 : nagbacalan
# City Count 417 : manicore
# City Count 418 : iralaya
# City Count 419 : san felipe
# City Count 420 : sujiatun
# City Count 421 : eureka
# City Count 422 : palu
# City not found! Skipping...
# City Count 423 : orchard homes
# City Count 424 : ankazobe
# City Count 425 : saldanha
# City Count 426 : kalevala
# City Count 427 : villazon
# City not found! Skipping...
# City Count 428 : passo de camaragibe
# City Count 429 : wau
# City Count 430 : ginir
# City Count 431 : na wa
# City Count 432 : wonthaggi
# City Count 433 : santa cruz
# City Count 434 : portland
# City Count 435 : mogadishu
# City Count 436 : east wenatchee bench
# City Count 437 : marco
# City not found! Skipping...
# City Count 438 : sibolga
# City Count 439 : hobyo
# City Count 440 : samaro
# City Count 441 : mattru
# City not found! Skipping...
# City Count 442 : mayahi
# City Count 443 : teloloapan
# City Count 444 : hasaki
# City Count 445 : charters towers
# City Count 446 : touros
# City Count 447 : ust-omchug
# City Count 448 : makakilo city
# City Count 449 : saint george
# City Count 450 : boyolangu
# City Count 451 : ayotzintepec
# City not found! Skipping...
# City Count 452 : nau
# City Count 453 : north bend
# City Count 454 : tena
# City Count 455 : abu kamal
# City Count 456 : caluquembe
# City Count 457 : marsa matruh
# City not found! Skipping...
# City Count 458 : mehamn
# City Count 459 : gizycko
# City not found! Skipping...
# City Count 460 : prescott valley
# City Count 461 : moron
# City Count 462 : tuatapere
# City Count 463 : tambovka
# City Count 464 : boden
# City not found! Skipping...
# City Count 465 : trincomalee
# City Count 466 : akyab
# City Count 467 : fortuna
# City Count 468 : lumsden
# City Count 469 : jinchang
# City Count 470 : christiana
# City Count 471 : verkhnetulomskiy
# City Count 472 : najran
# City Count 473 : kalemie
# City not found! Skipping...
# City Count 474 : kungurtug
# City Count 475 : nizhneangarsk
# City not found! Skipping...
# City Count 476 : lorengau
# City not found! Skipping...
# City not found! Skipping...
# City Count 477 : yazman
# City Count 478 : warrington
# City Count 479 : doha
# City Count 480 : young
# City Count 481 : kieta
# City Count 482 : omsukchan
# City Count 483 : neiafu
# City Count 484 : qaqortoq
# City Count 485 : necochea
# City Count 486 : tezu
# City Count 487 : caloundra
# City not found! Skipping...
# City not found! Skipping...
# City not found! Skipping...
# City Count 488 : flores
# City Count 489 : coolum beach
# City Count 490 : dire
# City Count 491 : dzilam gonzalez
# City Count 492 : coruripe
# City Count 493 : el reno
# City Count 494 : rosetta
# City Count 495 : pochutla
# City not found! Skipping...
# City Count 496 : narok
# City Count 497 : nioro
# City Count 498 : buchanan
# City Count 499 : akonolinga
# City Count 500 : mayya
# City Count 501 : mackay
# City not found! Skipping...
# City Count 502 : moba
# City Count 503 : lyuban
# City Count 504 : sabha
# City Count 505 : balkhash
# City Count 506 : coquimbo
# City Count 507 : parnaiba
# City Count 508 : japura
# City Count 509 : sarankhola
# City Count 510 : moose factory
# City Count 511 : ahuimanu
# City Count 512 : port macquarie
# City Count 513 : gorin
# City Count 514 : esperance
# City not found! Skipping...
# City Count 515 : baicheng
# City Count 516 : rocky mountain house
# City Count 517 : bambanglipuro
# City Count 518 : chara
# City Count 519 : tyret pervaya
# City Count 520 : luangwa
# City Count 521 : villarrica
# City Count 522 : vanavara
# City Count 523 : bengkulu
# City Count 524 : saint-doulchard
# City Count 525 : jiuquan
# City Count 526 : huainan
# City Count 527 : calamar
# City Count 528 : aykhal
# City Count 529 : samarai
# City Count 530 : sisimiut
# City Count 531 : mackenzie
# City Count 532 : columbus
# City Count 533 : onguday
# City Count 534 : carutapera
# City Count 535 : inuvik
# City Count 536 : monrovia
# City Count 537 : lenine
# City not found! Skipping...
# City Count 538 : san rafael
# City Count 539 : buala
# City Count 540 : shrewsbury
# City Count 541 : port hedland
# City Count 542 : dumas
# City Count 543 : adrar
# City Count 544 : banjar
# City Count 545 : viedma
# City Count 546 : sinnamary
# City Count 547 : beloha
# City not found! Skipping...
# City Count 548 : letterkenny
# City Count 549 : petrozavodsk
# City Count 550 : florida
# City Count 551 : gopalpur
# City Count 552 : maragogi
# City Count 553 : den chai
# City Count 554 : hirara
# City Count 555 : hamilton
# City Count 556 : horana
# City Count 557 : kokstad
# City Count 558 : evensk
# City Count 559 : pangnirtung
# City Count 560 : waddan
# City Count 561 : tateyama
# City Count 562 : san luis
# City Count 563 : umm kaddadah
# City Count 564 : gold coast
# City Count 565 : iskateley
# City Count 566 : nevelsk
# City Count 567 : monte alegre
# City Count 568 : cap malheureux
# City Count 569 : mariental
# City Count 570 : te anau
# City not found! Skipping...
# city name: ['Los Llanos de Aridane', 'Tuktoyaktuk', 'Maguling', 'Hualmay', 'Jamestown', 'Saint Paul Harbor', 'Arraial do Cabo', 'Carnarvon', 'Hilo', 'Margate', 'Ueda', 'Cidreira', 'Njombe', 'Ryōtsu-minato', 'Gamba', 'Longyearbyen', 'Mahon', 'Várzea Grande', 'Ambovombe', 'Lagoa', 'East London', 'Kenai', 'Beringovskiy', 'Nanortalik', 'Codrington', 'Mataura', 'Minyar', 'Kloulklubed', 'Barrow', 'Mollendo', 'George Town', 'Broome', 'Rønne', 'Kumul', 'Punta Arenas', 'Cabedelo', 'Pāvilosta', 'Hermanus', 'Coro', 'Lázaro Cárdenas', 'Biltine', 'Belaya Gora', 'Resen', 'Chadiza', 'Teya', 'Kruisfontein', 'Rikitea', 'Soyo', 'Hong Kong', 'Mahébourg', 'Kouroussa', 'Ushuaia', 'Alta Floresta', 'Chokurdakh', 'Egvekinot', 'San Joaquin', 'Kysyl-Syr', 'Saint-Philippe', 'Vallenar', 'Busselton', 'Tiksi', 'Roald', 'Souillac', 'Ancud', 'Airai', 'Faanui', 'Foz', 'Atuona', 'Qaanaaq', 'Hithadhoo', 'Ahipara', 'Port Alfred', 'Laï', 'Jinxiang', 'Cayenne', 'Balikpapan', 'Kapaa', 'Hobart', 'Chapais', 'Örnsköldsvik', 'Haines Junction', 'Muros', 'Mar del Plata', 'Pathein', 'Butaritari', 'Avarua', 'Dikson', 'Lüderitz', 'Diu', 'Kiryat Gat', 'Meulaboh', 'Boa Vista', 'Bathsheba', 'Khovd', 'Mossamedes', 'Sunrise Manor', 'Ribeira Grande', 'Tasiilaq', 'Santa Maria do Suaçuí', 'Mugan', 'Honiara', 'Las Margaritas', 'Castro', 'Lompoc', 'Abu Dhabi', 'Peterhead', 'Olafsvik', 'Nísia Floresta', 'Ginda', 'Dingle', 'Sandnessjøen', 'Saint-Lô', 'Port Elizabeth', 'Narsaq', 'Novyy Oskol', 'Chui', 'Puerto Nariño', 'Laguna', 'Bjerringbro', 'Quatre Cocos', 'Aksarka', 'College', 'Ambunti', 'Zaraza', 'Saint-Joseph', 'Bluff', 'Albany', 'Tagusao', 'Fairbanks', 'Khatanga', 'Mwinilunga', 'New Norfolk', 'Trofors', 'Emirdağ', 'Stromness', 'Bereda', 'Bambous Virieux', 'Jacareacanga', 'Mt. Pleasant', "Severo-Kuril'sk", 'Emerald', 'Birao', 'Umluj', 'Dwārka', 'Ribeirão Bonito', 'Lata', 'Norman Wells', 'Provideniya', 'Nianzishan', 'Kerrville', 'Grand Gaube', 'Atagay', 'Guozhen', 'Nikolskoye', 'Sitka', 'Yamada', 'Amur Oblast', 'Ilulissat', 'Takoradze', 'Upernavik', 'Kavaratti', 'Havelock', 'Homer', 'Damietta', 'Winnemucca', 'Vaini', 'Porosozero', 'Poum', 'Port Hardy', 'Saint-François', 'Orlik', 'Tromsø', 'Kirakira', 'Ikom', 'Anadyr', 'Geraldton', 'Vila Franca do Campo', 'Cabatuan', 'La Orilla', 'Selishche', 'Yangi Marg`ilon', 'Isangel', 'Flin Flon', 'Kangaatsiaq', 'Barra de Tecoanapa', 'Novyy Svit', 'Bakchar', 'Kaitangata', 'Naze', 'Nuuk', 'Povenets', 'Yellowknife', 'Bredasdorp', 'Genç', 'Moshupa', 'Cape Town', 'Halifax', 'Livingston', 'Constantine', 'Rafaela', 'Bethanien', 'Talnakh', 'Ponta do Sol', 'Silifke', 'Leningradskiy', 'Alice Town', 'Khani', 'Calatayud', 'Morondava', 'Shenjiamen', 'Wanning', 'Aragarças', 'Arti', 'Doka', 'Xingtai', 'Landau', 'Bonfim', 'Alofi', 'Henties Bay', 'Biak', 'Basco', 'Kazanskoye', 'Flinders', 'Petropavl', 'Andros Town', 'La Paz', 'Puerto Ayora', 'Moose Jaw', 'Pio XII', "Ust'-Ilimsk", 'Biu', 'Araouane', 'Elizabeth City', 'Ukiah', 'Banjarmasin', 'Xining', 'Kahului', 'Kavieng', 'Miraflores', 'Yerbogachën', 'Kelvington', "Tigil'", 'Avera', 'Camacupa', 'San Patricio', 'Sabang', 'Alice Springs', 'Westport', 'Vorotynets', 'Port-Gentil', 'Lebu', 'Chimbote', 'Verāval', 'Rawson', 'Baykit', 'Moen', 'Cabo San Lucas', 'Chifeng', 'Cherskiy', 'Mersing', 'Labuhan', 'Okhotsk', 'Ranong', 'Faya', 'Argelia', 'São Sebastião', 'Shyryayeve', 'Constitución', 'Teberda', 'Tupik', 'Lavrentiya', 'San Quintín', 'Saskylakh', 'Salalah', 'Aleksandrov Gay', 'Colorines', 'Terrace', 'Acapulco de Juárez', 'Tilichiki', 'Ambilobe', 'Preiļi', 'Campo Grande', 'Chardara', 'Hofn', 'Hambantota', 'Kitob', 'Blagoyevo', 'Novobelokatay', 'Ubari', 'Singaparna', 'Kaniama', 'Marawi', 'Znamenskoye', 'Thompson', 'Bansang', 'La Ronge', 'Sur', 'Beeville', 'Nemuro', 'Saquisilí', 'Hargeisa', 'Lleida', 'Uvinza', 'Nādbai', 'Cabinda', 'Perth', 'Zaragoza', 'Nur-Sultan', 'Bitung', 'Kibala', 'Erzin', 'Ambon City', 'Cairns', 'Rincon', 'Zapadnaya Dvina', 'Gombong', 'Santa Maria', 'Bethel', 'Taldan', 'Padang', 'Clyde River', 'Gri ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_weather_data_df = pd.DataFrame({"City":name,
                                     "Latitude":lat,
                                     "Longitude":long,
                                     "Date":date,
                                     "Temperature (F)": temp,
                                     "Temp Max":temp_max,
                                     "Humidity (%)":humidity,
                                     "Cloudiness (%)":cloudy,
                                     "Windspeed (mph)":windspeed})
city_weather_data_df.to_csv(output_data)
city_weather_data_df
# Out:
#                       City  Latitude  Longitude        Date  Temperature (F)  \
# 0    Los Llanos de Aridane     28.66     -17.92  1600202506            75.07
# 1              Tuktoyaktuk     69.45    -133.04  1600202506            32.00
# 2                 Maguling      6.09     124.40  1600202506            77.41
# 3                  Hualmay    -11.10     -77.61  1600202506            64.94
# 4                Jamestown     42.10     -79.24  1600202506            64.08
# ..                     ...       ...        ...         ...              ...
# 579                 Helong     42.54     129.00  1600202575            53.51
# 580               Goderich     43.75     -81.72  1600202391            68.00
# 581                  Nioki     -2.72      17.68  1600202576            76.96
# 582           Bogorodskoye     56.55      37.88  1600202576            44.51
# 583                Malakal      9.53      31.66  1600202576            73.78
#
#      Temp Max  Humidity (%)  Cloudiness (%)  Windspeed (mph)
# 0       75.20            78              20            11.41
# 1       32.00            80              90            11.41
# 2       77.41            85             100             4.03
# 3       64.94            72              34             9.53
# 4       66.00            48               1             3.36
# ..        ...           ...             ...              ...
# 579     53.51            86             100             2.59
# 580     71.01            65              81            19.69
# 581     76.96            81              88             2.57
# 582     44.51            87               0             7.45
# 583     73.78            86              38             3.18
#
# [584 rows x 9 columns]

# %%
city_weather_data_df.count()
# Out:
# City               584
# Latitude           584
# Longitude          584
# Date               584
# Temperature (F)    584
# Temp Max           584
# Humidity (%)       584
# Cloudiness (%)     584
# Windspeed (mph)    584
# dtype: int64

# %%
city_weather_data_df.describe()
# Out:
#          Latitude   Longitude          Date  Temperature (F)    Temp Max  \
# count  584.000000  584.000000  5.840000e+02       584.000000  584.000000
# mean    20.411541   17.664589  1.600203e+09        65.985445   66.334503
# std     32.910140   90.723172  6.892965e+01        15.302189   15.404056
# min    -54.800000 -179.170000  1.600202e+09        21.780000   21.780000
# 25%     -6.385000  -63.042500  1.600203e+09        53.600000   53.600000
# 50%     22.300000   21.625000  1.600203e+09        67.440000   67.965000
# 75%     50.112500   98.970000  1.600203e+09        78.317500   78.800000
# max     78.220000  179.320000  1.600203e+09       102.740000  102.740000
#
#        Humidity (%)  Cloudiness (%)  Windspeed (mph)
# count    584.000000      584.000000       584.000000
# mean      70.782534       57.068493         7.646524
# std       21.727984       38.261429         5.429911
# min        1.000000        0.000000         0.090000
# 25%       58.000000       20.000000         3.235000
# 50%       77.000000       72.500000         6.410000
# 75%       88.000000       94.000000        10.785000
# max      100.000000      100.000000        28.880000

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#create scatter plot latitude vs max temp
plt.scatter(city_weather_data_df['Latitude'], city_weather_data_df['Temp Max'], marker="o", edgecolors="black")
plt.title("Latitude of Cities vs. Max Temperature on 15Sep2020")
plt.xlabel("Latitude of Cities")
plt.ylabel("Max Temperature (F)")
plt.grid()
plt.savefig("Images/scatter_lat_vs_maxtemp.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#create scatter plot latitude vs humidity
plt.scatter(city_weather_data_df['Latitude'], city_weather_data_df['Humidity (%)'], marker="o", edgecolors="black")
plt.title("Latitude of Cities vs. Humidity on 15Sep2020")
plt.xlabel("Latitude of Cities")
plt.ylabel("Humidity %")
plt.grid()
plt.savefig("Images/scatter_lat_vs_humidity.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
#create scatter plot latitude vs cloudiness
plt.scatter(city_weather_data_df['Latitude'], city_weather_data_df['Cloudiness (%)'], marker="o", edgecolors="black")
plt.title("Latitude of Cities vs. Cloudiness on 15Sep2020")
plt.xlabel("Latitude of Cities")
plt.ylabel("Cloudiness %")
plt.grid()
plt.savefig("Images/scatter_lat_vs_cloudiness.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
#create scatter plot latitude vs wind speed
plt.scatter(city_weather_data_df['Latitude'], city_weather_data_df['Windspeed (mph)'], marker="o", edgecolors="black")
plt.title("Latitude of Cities vs. Wind Speed on 15Sep2020")
plt.xlabel("Latitude of Cities")
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.savefig("Images/scatter_lat_vs_windspeed.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
north_weather_df = city_weather_data_df.loc[city_weather_data_df["Latitude"] >= 0]
north_weather_df
# Out:
#                       City  Latitude  Longitude        Date  Temperature (F)  \
# 0    Los Llanos de Aridane     28.66     -17.92  1600202506            75.07
# 1              Tuktoyaktuk     69.45    -133.04  1600202506            32.00
# 2                 Maguling      6.09     124.40  1600202506            77.41
# 4                Jamestown     42.10     -79.24  1600202506            64.08
# 5        Saint Paul Harbor     57.79    -152.41  1600202506            53.80
# ..                     ...       ...        ...         ...              ...
# 578               Øksfjord     70.24      22.35  1600202575            45.14
# 579                 Helong     42.54     129.00  1600202575            53.51
# 580               Goderich     43.75     -81.72  1600202391            68.00
# 582           Bogorodskoye     56.55      37.88  1600202576            44.51
# 583                Malakal      9.53      31.66  1600202576            73.78
#
#      Temp Max  Humidity (%)  Cloudiness (%)  Windspeed (mph)
# 0       75.20            78              20            11.41
# 1       32.00            80              90            11.41
# 2       77.41            85             100             4.03
# 4       66.00            48               1             3.36
# 5       53.80            94              91            14.58
# ..        ...           ...             ...              ...
# 578     46.40            93              75             5.82
# 579     53.51            86             100             2.59
# 580     71.01            65              81            19.69
# 582     44.51            87               0             7.45
# 583     73.78            86              38             3.18
#
# [401 rows x 9 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#locate all data >=0 latitude in new df
north_weather_df = city_weather_data_df.loc[city_weather_data_df["Latitude"] >= 0]
north_weather_df
x_values = north_weather_df['Latitude']
y_values = north_weather_df['Temp Max']
#create scatter plot northern latitudes vs max temp
plt.scatter(x_values, y_values, marker="o", edgecolors="black")
plt.title("Latitude of Cities in Northern Hemisphere vs. Max Temperature on 15Sep2020")
plt.xlabel("Latitude of Cities")
plt.ylabel("Max Temperature (F)")
plt.grid()
#regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
r_squared = rvalue**2
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,100),fontsize=12,color="red")

#save & show
plt.savefig("Images/scatter_NORTH_lat_vs_maxtemp_regression.png")
plt.show()
print(f"The r-squared is: {r_squared}")
# Out:
# The r-squared is: 0.6678868584842982

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
south_weather_df = city_weather_data_df.loc[city_weather_data_df["Latitude"] < 0]
south_weather_df
x_values = south_weather_df['Latitude']
y_values = south_weather_df['Temp Max']
#create scatter plot southern latitudes vs max temp
plt.scatter(south_weather_df['Latitude'], south_weather_df['Temp Max'], marker="o", edgecolors="black")
plt.title("Latitude of Cities in Southern Hemisphere vs. Max Temperature on 15Sep2020")
plt.xlabel("Latitude of Cities")
plt.ylabel("Max Temperature (F)")
plt.grid()

#regression 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
r_squared = rvalue**2
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,45),fontsize=12,color="red")

#save & show
plt.savefig("Images/scatter_SOUTH_lat_vs_maxtemp_regression.png")
plt.show()
print(f"The r-squared is: {r_squared}")
# Out:
# The r-squared is: 0.513890117180917

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#set x & y values
x_values = north_weather_df['Latitude']
y_values = north_weather_df['Humidity (%)']
#create scatter plot northern latitudes vs max temp
plt.scatter(x_values, y_values, marker="o", edgecolors="black")
plt.title("Latitude of Cities in Northern Hemisphere vs. Humidity (%) on 15Sep2020")
plt.xlabel("Latitude of Cities")
plt.ylabel("Humidity (%)")
plt.grid()
#regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
r_squared = rvalue**2
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50,20),fontsize=12,color="red")

#save & show
plt.savefig("Images/scatter_NORTH_lat_vs_humidity_regression.png")
plt.show()
print(f"The r-squared is: {r_squared}")
# Out:
# The r-squared is: 0.0075764741470975335

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#set x & y values
x_values = south_weather_df['Latitude']
y_values = south_weather_df['Humidity (%)']
#create scatter plot southern latitudes vs max temp
plt.scatter(x_values, y_values, marker="o", edgecolors="black")
plt.title("Latitude of Cities in Southern Hemisphere vs. Humidity (%) on 15Sep2020")
plt.xlabel("Latitude of Cities")
plt.ylabel("Humidity (%)")
plt.grid()

#regression 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
r_squared = rvalue**2
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50, 50),fontsize=12,color="red")

#save & show
plt.savefig("Images/scatter_SOUTH_lat_vs_humidity_regression.png")
plt.show()
print(f"The r-squared is: {r_squared}")
# Out:
# The r-squared is: 0.022512254656274867

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#set x & y values
x_values = north_weather_df['Latitude']
y_values = north_weather_df['Cloudiness (%)']
#create scatter plot northern latitudes vs max temp
plt.scatter(x_values, y_values, marker="o", edgecolors="black")
plt.title("Latitude of Cities in Northern Hemisphere vs. Cloudiness (%) on 15Sep2020")
plt.xlabel("Latitude of Cities")
plt.ylabel("Cloudiness (%)")
plt.grid()
#regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
r_squared = rvalue**2
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(12,30),fontsize=10,color="red")

#save & show
plt.savefig("Images/scatter_NORTH_lat_vs_cloudiness_regression.png")
plt.show()
print(f"The r-squared is: {r_squared}")
# Out:
# The r-squared is: 0.0009238298217280005

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#set x & y values
x_values = south_weather_df['Latitude']
y_values = south_weather_df['Cloudiness (%)']
#create scatter plot southern latitudes vs max temp
plt.scatter(x_values, y_values, marker="o", edgecolors="black")
plt.title("Latitude of Cities in Southern Hemisphere vs. Cloudiness (%) on 15Sep2020")
plt.xlabel("Latitude of Cities")
plt.ylabel("Cloudiness (%)")
plt.grid()

#regression 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
r_squared = rvalue**2
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55, 60),fontsize=12,color="red")

#save & show
plt.savefig("Images/scatter_SOUTH_lat_vs_cloudiness_regression.png")
plt.show()
print(f"The r-squared is: {r_squared}")
# Out:
# The r-squared is: 0.001708149897415676

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#set x & y values
x_values = north_weather_df['Latitude']
y_values = north_weather_df['Windspeed (mph)']
#create scatter plot northern latitudes vs max temp
plt.scatter(x_values, y_values, marker="o", edgecolors="black")
plt.title("Latitude of Cities in Northern Hemisphere vs. Windspeed on 15Sep2020")
plt.xlabel("Latitude of Cities")
plt.ylabel("Windspeed (mph)")
plt.grid()
#regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
r_squared = rvalue**2
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(10,25),fontsize=12,color="red")

#save & show
plt.savefig("Images/scatter_NORTH_lat_vs_windspeed_regression.png")
plt.show()
print(f"The r-squared is: {r_squared}")
# Out:
# The r-squared is: 0.001528791371343609

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#set x & y values
x_values = south_weather_df['Latitude']
y_values = south_weather_df['Windspeed (mph)']
#create scatter plot southern latitudes vs max temp
plt.scatter(x_values, y_values, marker="o", edgecolors="black")
plt.title("Latitude of Cities in Southern Hemisphere vs. Windspeed on 15Sep2020")
plt.xlabel("Latitude of Cities")
plt.ylabel("Windspeed (mph)")
plt.grid()

#regression 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
r_squared = rvalue**2
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55, 11),fontsize=10,color="red")

#save & show
plt.savefig("Images/scatter_SOUTH_lat_vs_windspeed_regression.png")
plt.show()
print(f"The r-squared is: {r_squared}")
# Out:
# The r-squared is: 0.01681409953563703
